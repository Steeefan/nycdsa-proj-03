# %%
import pandas as pd
full_df = pd.read_csv('split_df.csv', sep = '|')
df2 = pd.read_csv('feats.csv')
df2 = df2.ix[:,1:3]

# %%
full_df = full_df.merge(df2)

# %%
#full_df.loc[(full_df['Interest_Level']=='high')]
#filter(full_df, full_df.ix[:,'features'] != None)
#full_df[pd.isnull(full_df.features) == True]
#notfull_df.ix[92,'features']
full_df = full_df.fillna(value = 'No_Features')
full_df.head()
# Out:
#    aptID  bathrooms  bedrooms                       building_id  \
# 0      4        1.0         1  8579a0b0d54db803821a35a4a615e97a
# 1      6        1.0         2  b8e75fc949a6cd8225b455648a951712
# 2      9        1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 3     10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 4     15        1.0         0  bfb9405149bfff42a92980b594c28234
#
#                                          description  latitude  longitude  \
# 0  Spacious 1 Bedroom 1 Bathroom in Williamsburg ...   40.7108   -73.9539
# 1  BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...   40.7513   -73.9722
# 2    FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL  L...   40.7575   -73.9625
# 3  A Brand New 3 Bedroom 1 5 bath ApartmentEnjoy ...   40.7145   -73.9425
# 4  Over sized Studio w abundant closets  Availabl...   40.7439   -73.9743
#
#    price interest_level  created.Day  \
# 0   2400         medium           16
# 1   3800            low            1
# ...

# %%
full_df.loc[2,'Low']
# Out:
# False

# %%
"""import pandas as pd
full_df = pd.read_csv('full_df.csv', H)
df2 = pd.read_csv('feats.csv', sep = '|')
"""
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import euclidean_distances


import nltk
from nltk.tag import pos_tag
from nltk import word_tokenize
from nltk.corpus import stopwords

stop = stopwords.words('english')
def cleaning_feats(sentence):
    sentence=re.sub('[^\w\s]',' ', sentence) #removes punctuations
    sentence=re.sub('_',' ', sentence) #removes punctuations
    sentence=re.sub('\d+',' ', sentence) #removes digits
    cleaned=' '.join([w for w in sentence.split() if not w in stop]) # removes english stopwords
    #cleaned=' '.join([w for w , pos in pos_tag(cleaned.split()) if (pos == 'NN' or pos=='JJ' or pos=='JJR' or pos=='JJS' )])
    
    #selecting only nouns and adjectives
    cleaned=' '.join([w for w in cleaned.split() if not len(w)<=2 ]) #removes single lettered words and digits
    cleaned= cleaned.strip()
    return cleaned
	  
full_df['cln_feats'] = map(lambda x: cleaning_feats(x), full_df['features'])


data_high=full_df.loc[(full_df['interest_level']=='high')]
data_medium=full_df.loc[(full_df['interest_level']=='medium')]
data_low=full_df.loc[(full_df['interest_level']=='low')]

binVectorizer = CountVectorizer(binary=True)
feats_hml = binVectorizer.fit_transform(full_df['cln_feats']) #dividing into high medium and low
full_df.head()
# Out:
#    aptID  bathrooms  bedrooms                       building_id  \
# 0      4        1.0         1  8579a0b0d54db803821a35a4a615e97a
# 1      6        1.0         2  b8e75fc949a6cd8225b455648a951712
# 2      9        1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 3     10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 4     15        1.0         0  bfb9405149bfff42a92980b594c28234
#
#                                          description  latitude  longitude  \
# 0  Spacious 1 Bedroom 1 Bathroom in Williamsburg ...   40.7108   -73.9539
# 1  BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...   40.7513   -73.9722
# 2    FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL  L...   40.7575   -73.9625
# 3  A Brand New 3 Bedroom 1 5 bath ApartmentEnjoy ...   40.7145   -73.9425
# 4  Over sized Studio w abundant closets  Availabl...   40.7439   -73.9743
#
#    price interest_level  created.Day  \
# 0   2400         medium           16
# 1   3800            low            1
# ...

# %%
#separating for Naive bayes on high and medium vs Low
data_hm = full_df.loc[(full_df['Low']== False)]
data_l =full_df.loc[(full_df['Low']== True)]

#separating for Naive bayes on high vs medium and Low
data_h = full_df.loc[(full_df['High']== True)]
data_ml = full_df.loc[(full_df['High']== True)]
full_df.head()
# Out:
#    aptID  bathrooms  bedrooms                       building_id  \
# 0      4        1.0         1  8579a0b0d54db803821a35a4a615e97a
# 1      6        1.0         2  b8e75fc949a6cd8225b455648a951712
# 2      9        1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 3     10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 4     15        1.0         0  bfb9405149bfff42a92980b594c28234
#
#                                          description  latitude  longitude  \
# 0  Spacious 1 Bedroom 1 Bathroom in Williamsburg ...   40.7108   -73.9539
# 1  BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...   40.7513   -73.9722
# 2    FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL  L...   40.7575   -73.9625
# 3  A Brand New 3 Bedroom 1 5 bath ApartmentEnjoy ...   40.7145   -73.9425
# 4  Over sized Studio w abundant closets  Availabl...   40.7439   -73.9743
#
#    price interest_level  created.Day  \
# 0   2400         medium           16
# 1   3800            low            1
# ...

# %%
#prepare to train for low values
from sklearn.naive_bayes import MultinomialNB
classifier_low = MultinomialNB()
targets_low = full_df['Low'].values
classifier_low.fit(feats_hml, targets_low)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#do stuff for low values

examples = full_df['cln_feats']
example_counts = binVectorizer.transform(examples)
predictions = classifier_low.predict(example_counts)
predictions_df=pd.DataFrame(predictions)
predictions_df.head(10)
actual_low=full_df['Low'].values
from sklearn.metrics import confusion_matrix
matrix=pd.DataFrame(confusion_matrix(actual_low, predictions,labels=[False, True]))
print(matrix)

#pd.crosstab(full_df['Interest_Level'], predictions, rownames=['True'], colnames=['Predicted'], margins=True)
#predictions
import numpy as np
import pandas as pd
import scipy.sparse as sparse

full_df['pred_low'] = predictions.tolist()
full_df.head()
# Out:
#       0      1
# 0  2974  12094
# 1  3189  31095
#    aptID  bathrooms  bedrooms                       building_id  \
# 0      4        1.0         1  8579a0b0d54db803821a35a4a615e97a
# 1      6        1.0         2  b8e75fc949a6cd8225b455648a951712
# 2      9        1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 3     10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 4     15        1.0         0  bfb9405149bfff42a92980b594c28234
#
#                                          description  latitude  longitude  \
# 0  Spacious 1 Bedroom 1 Bathroom in Williamsburg ...   40.7108   -73.9539
# 1  BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...   40.7513   -73.9722
# 2    FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL  L...   40.7575   -73.9625
# 3  A Brand New 3 Bedroom 1 5 bath ApartmentEnjoy ...   40.7145   -73.9425
# 4  Over sized Studio w abundant closets  Availabl...   40.7439   -73.9743
#
#    price interest_level  created.Day   ...    mgrHighPct  mgrLowPct  \
# ...

# %%
#prepare to train for low values
classifier_low = MultinomialNB()
targets_low = full_df['Low'].values
classifier_low.fit(feats_hml, targets_low)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#Prepare to train for high valuesclassifier = MultinomialNB()
classifier_high = MultinomialNB()
targets_high = full_df['High'].values
classifier_high.fit(feats_hml, targets_high)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
examples = full_df['cln_feats']
example_counts = binVectorizer.transform(examples)
predictions = classifier_high.predict(example_counts)
predictions_df=pd.DataFrame(predictions)
predictions_df.head(10)
actual=full_df['High'].values
from sklearn.metrics import confusion_matrix
matrix=pd.DataFrame(confusion_matrix(actual, predictions,labels=[False, True]))
print(matrix)

#pd.crosstab(full_df['Interest_Level'], predictions, rownames=['True'], colnames=['Predicted'], margins=True)
#predictions
import numpy as np
import pandas as pd
import scipy.sparse as sparse

full_df['pred_high'] = predictions.tolist()
full_df.head()
# Out:
#        0    1
# 0  44690  823
# 1   3600  239
#    aptID  bathrooms  bedrooms                       building_id  \
# 0      4        1.0         1  8579a0b0d54db803821a35a4a615e97a
# 1      6        1.0         2  b8e75fc949a6cd8225b455648a951712
# 2      9        1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 3     10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 4     15        1.0         0  bfb9405149bfff42a92980b594c28234
#
#                                          description  latitude  longitude  \
# 0  Spacious 1 Bedroom 1 Bathroom in Williamsburg ...   40.7108   -73.9539
# 1  BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...   40.7513   -73.9722
# 2    FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL  L...   40.7575   -73.9625
# 3  A Brand New 3 Bedroom 1 5 bath ApartmentEnjoy ...   40.7145   -73.9425
# 4  Over sized Studio w abundant closets  Availabl...   40.7439   -73.9743
#
#    price interest_level  created.Day    ...    mgrLowPct  bldgHighPct  \
# ...

# %%
#high or med only
part_df = pd.DataFrame(full_df.loc[(full_df['Low'] == False)])
feats_hm = binVectorizer.fit_transform(part_df['cln_feats'])

from sklearn.naive_bayes import MultinomialNB
classifier_h_m = MultinomialNB()
targets_h_m = part_df['interest_level'].values
classifier_h_m.fit(feats_hm, targets_h_m)

examples = part_df['cln_feats']
example_counts = binVectorizer.transform(examples)
predictions = classifier_h_m.predict(example_counts)
predictions_df=pd.DataFrame(predictions)
predictions_df.head(10)
actual=part_df['interest_level'].values
from sklearn.metrics import confusion_matrix
matrix=pd.DataFrame(confusion_matrix(actual, predictions, labels=["medium", "high"]))
print(matrix)

#pd.crosstab(full_df['Interest_Level'], predictions, rownames=['True'], colnames=['Predicted'], margins=True)
#predictions
import numpy as np
import pandas as pd
import scipy.sparse as sparse

part_df['pred_h_or_m'] = predictions.tolist()
part_df.head()
# Out:
#        0    1
# 0  10822  407
# 1   3556  283
#     aptID  bathrooms  bedrooms                       building_id  \
# 0       4        1.0         1  8579a0b0d54db803821a35a4a615e97a
# 2       9        1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 3      10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 7      19        1.0         0  d48767c37a934daaf0bbb0e58c755d0c
# 12     38        1.0         0  2787598123c55dbf45b514958909c79c
#
#                                           description  latitude  longitude  \
# 0   Spacious 1 Bedroom 1 Bathroom in Williamsburg ...   40.7108   -73.9539
# 2     FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL  L...   40.7575   -73.9625
# 3   A Brand New 3 Bedroom 1 5 bath ApartmentEnjoy ...   40.7145   -73.9425
# 7   No Fee Large Renovated Sun Splashed Studio  Wa...   40.7769   -73.9467
# 12  This is a luxurious JR 1 bedroom with tons of ...   40.7610   -73.9990
#
# ...

# %%
full_df.to_csv('fine_tune_NB.csv')
part_df.to_csv('partfine_tune_NB.csv')

#full_df.loc[(full_df['h_m'] != 'prob_low')]['h_m'].head()
